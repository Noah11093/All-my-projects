# %%
import numpy as np
import tensorflow as tf
from scipy.io import loadmat
from sklearn.decomposition import IncrementalPCA
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report

# Load data
data = loadmat("umist_cropped.mat")['facedat'][0]
face, target = [], []
label = 0
for batch in data:
    for sample in batch.T:
        sample = sample.T.reshape(-1)
        face.append(sample)
        target.append(label)
    label += 1
face, target = np.array(face), np.array(target)

# %%
# Encode target labels
label_encoder = LabelEncoder()
encoded_target = label_encoder.fit_transform(target)

# %%
# Feature reduction with Incremental PCA
pca = IncrementalPCA(n_components=260)
face_reduced = pca.fit_transform(face)

# %%
# Clustering with Gaussian Mixture Model
gmm = GaussianMixture(n_components=20, covariance_type='spherical').fit(face_reduced)
new_face, new_target = gmm.sample(1000)
new_target = tf.keras.utils.to_categorical(new_target, num_classes=label)

# %%
# Stratified Splitting of the dataset
x_train, x_temp, y_train, y_temp = train_test_split(new_face, new_target, test_size=0.4, stratify=new_target, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, stratify=y_temp, random_state=42)

# %%
# Model Definition
def create_deep_and_cross_model(input_shape, num_classes, hidden_units=[64, 64]):
    input_layer = tf.keras.Input(shape=input_shape)

    # Cross Network
    cross = input_layer
    for _ in hidden_units:
        units = input_layer.shape[-1]
        x = tf.keras.layers.Dense(units, kernel_regularizer='l2')(input_layer)
        cross = input_layer * x + cross
    cross = tf.keras.layers.BatchNormalization()(cross)

    # Deep Network
    deep = input_layer
    for units in hidden_units:
        deep = tf.keras.layers.Dense(units, kernel_regularizer='l2')(deep)
        deep = tf.keras.layers.BatchNormalization()(deep)
        deep = tf.keras.layers.ReLU()(deep)

    # Combine Networks
    merged = tf.keras.layers.concatenate([cross, deep])
    output_layer = tf.keras.layers.Dense(units=num_classes, activation='softmax')(merged)
    model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
    model.compile(loss='categorical_crossentropy', optimizer='Adamax', metrics=['accuracy'])
    return model

# %%
# Create and Train the Model
model = create_deep_and_cross_model(input_shape=x_train.shape[1:], num_classes=label)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=2)
model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=100, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 10ms/step - loss: 10.1726 - accuracy: 0.0817 - val_loss: 11.9153 - val_accuracy: 0.1050
# Epoch 2/100
# 19/19 [==============================] - 0s 3ms/step - loss: 8.6663 - accuracy: 0.3300 - val_loss: 9.8992 - val_accuracy: 0.1700
# Epoch 3/100
# 19/19 [==============================] - 0s 3ms/step - loss: 7.6898 - accuracy: 0.5950 - val_loss: 8.8458 - val_accuracy: 0.2300
# Epoch 4/100
# 19/19 [==============================] - 0s 3ms/step - loss: 6.9631 - accuracy: 0.8100 - val_loss: 8.1117 - val_accuracy: 0.3400
# Epoch 5/100
# 19/19 [==============================] - 0s 3ms/step - loss: 6.3774 - accuracy: 0.9117 - val_loss: 7.5438 - val_accuracy: 0.4200
# Epoch 6/100
# 19/19 [==============================] - 0s 3ms/step - loss: 5.9209 - accuracy: 0.9717 - val_loss: 7.0771 - val_accuracy: 0.4950
# Epoch 7/100
# 19/19 [==============================] - 0s 3ms/step - loss: 5.5400 - accuracy: 0.9833 - val_loss: 6.6790 - val_accuracy: 0.5750
# Epoch 8/100
# 19/19 [==============================] - 0s 3ms/step - loss: 5.2266 - accuracy: 0.9950 - val_loss: 6.3266 - val_accuracy: 0.6200
# Epoch 9/100
# 19/19 [==============================] - 0s 3ms/step - loss: 4.9300 - accuracy: 0.9983 - val_loss: 6.0075 - val_accuracy: 0.6650
# Epoch 10/100
# 19/19 [==============================] - 0s 3ms/step - loss: 4.6734 - accuracy: 1.0000 - val_loss: 5.7172 - val_accuracy: 0.6850
# Epoch 11/100
# 19/19 [==============================] - 0s 3ms/step - loss: 4.4345 - accuracy: 1.0000 - val_loss: 5.4468 - val_accuracy: 0.7150
# Epoch 12/100
# 19/19 [==============================] - 0s 3ms/step - loss: 4.2122 - accuracy: 1.0000 - val_loss: 5.1932 - val_accuracy: 0.7200
# Epoch 13/100
# 19/19 [==============================] - 0s 3ms/step - loss: 4.0022 - accuracy: 1.0000 - val_loss: 4.9532 - val_accuracy: 0.7400
# Epoch 14/100
# 19/19 [==============================] - 0s 3ms/step - loss: 3.8078 - accuracy: 1.0000 - val_loss: 4.7239 - val_accuracy: 0.7600
# Epoch 15/100
# 19/19 [==============================] - 0s 3ms/step - loss: 3.6199 - accuracy: 1.0000 - val_loss: 4.5060 - val_accuracy: 0.7750
# Epoch 16/100
# 19/19 [==============================] - 0s 3ms/step - loss: 3.4364 - accuracy: 1.0000 - val_loss: 4.3002 - val_accuracy: 0.7900
# Epoch 17/100
# 19/19 [==============================] - 0s 3ms/step - loss: 3.2610 - accuracy: 1.0000 - val_loss: 4.1044 - val_accuracy: 0.7950
# Epoch 18/100
# 19/19 [==============================] - 0s 3ms/step - loss: 3.0986 - accuracy: 1.0000 - val_loss: 3.9167 - val_accuracy: 0.8100
# Epoch 19/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.9357 - accuracy: 1.0000 - val_loss: 3.7403 - val_accuracy: 0.8200
# Epoch 20/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.7826 - accuracy: 1.0000 - val_loss: 3.5713 - val_accuracy: 0.8200
# Epoch 21/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.6391 - accuracy: 1.0000 - val_loss: 3.4078 - val_accuracy: 0.8250
# Epoch 22/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.5080 - accuracy: 1.0000 - val_loss: 3.2497 - val_accuracy: 0.8400
# Epoch 23/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.3681 - accuracy: 1.0000 - val_loss: 3.0998 - val_accuracy: 0.8400
# Epoch 24/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.2430 - accuracy: 1.0000 - val_loss: 2.9572 - val_accuracy: 0.8450
# Epoch 25/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.1207 - accuracy: 1.0000 - val_loss: 2.8228 - val_accuracy: 0.8450
# Epoch 26/100
# 19/19 [==============================] - 0s 3ms/step - loss: 2.0053 - accuracy: 1.0000 - val_loss: 2.6947 - val_accuracy: 0.8500
# Epoch 27/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.8974 - accuracy: 1.0000 - val_loss: 2.5713 - val_accuracy: 0.8600
# Epoch 28/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.7886 - accuracy: 1.0000 - val_loss: 2.4537 - val_accuracy: 0.8650
# Epoch 29/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.6903 - accuracy: 1.0000 - val_loss: 2.3400 - val_accuracy: 0.8650
# Epoch 30/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.5970 - accuracy: 1.0000 - val_loss: 2.2322 - val_accuracy: 0.8650
# Epoch 31/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.5028 - accuracy: 1.0000 - val_loss: 2.1300 - val_accuracy: 0.8700
# Epoch 32/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.4157 - accuracy: 1.0000 - val_loss: 2.0352 - val_accuracy: 0.8700
# Epoch 33/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.3358 - accuracy: 1.0000 - val_loss: 1.9427 - val_accuracy: 0.8700
# Epoch 34/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.2580 - accuracy: 1.0000 - val_loss: 1.8542 - val_accuracy: 0.8700
# Epoch 35/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.1839 - accuracy: 1.0000 - val_loss: 1.7704 - val_accuracy: 0.8700
# Epoch 36/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.1148 - accuracy: 1.0000 - val_loss: 1.6913 - val_accuracy: 0.8750
# Epoch 37/100
# 19/19 [==============================] - 0s 3ms/step - loss: 1.0491 - accuracy: 1.0000 - val_loss: 1.6176 - val_accuracy: 0.8750
# Epoch 38/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.9874 - accuracy: 1.0000 - val_loss: 1.5444 - val_accuracy: 0.8750
# Epoch 39/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.9261 - accuracy: 1.0000 - val_loss: 1.4762 - val_accuracy: 0.8750
# Epoch 40/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.8696 - accuracy: 1.0000 - val_loss: 1.4121 - val_accuracy: 0.8750
# Epoch 41/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.8163 - accuracy: 1.0000 - val_loss: 1.3504 - val_accuracy: 0.8850
# Epoch 42/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.7666 - accuracy: 1.0000 - val_loss: 1.2954 - val_accuracy: 0.8800
# Epoch 43/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.7216 - accuracy: 1.0000 - val_loss: 1.2390 - val_accuracy: 0.8800
# Epoch 44/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6748 - accuracy: 1.0000 - val_loss: 1.1867 - val_accuracy: 0.8850
# Epoch 45/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6343 - accuracy: 1.0000 - val_loss: 1.1387 - val_accuracy: 0.8900
# Epoch 46/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.5945 - accuracy: 1.0000 - val_loss: 1.0938 - val_accuracy: 0.8900
# Epoch 47/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.5557 - accuracy: 1.0000 - val_loss: 1.0505 - val_accuracy: 0.8900
# Epoch 48/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.5216 - accuracy: 1.0000 - val_loss: 1.0080 - val_accuracy: 0.8900
# Epoch 49/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4886 - accuracy: 1.0000 - val_loss: 0.9689 - val_accuracy: 0.8900
# Epoch 50/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4580 - accuracy: 1.0000 - val_loss: 0.9357 - val_accuracy: 0.8850
# Epoch 51/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4292 - accuracy: 1.0000 - val_loss: 0.9019 - val_accuracy: 0.8850
# Epoch 52/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4024 - accuracy: 1.0000 - val_loss: 0.8677 - val_accuracy: 0.8800
# Epoch 53/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3763 - accuracy: 1.0000 - val_loss: 0.8393 - val_accuracy: 0.8850
# Epoch 54/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3530 - accuracy: 1.0000 - val_loss: 0.8098 - val_accuracy: 0.8900
# Epoch 55/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3308 - accuracy: 1.0000 - val_loss: 0.7795 - val_accuracy: 0.9050
# Epoch 56/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3111 - accuracy: 1.0000 - val_loss: 0.7489 - val_accuracy: 0.9000
# Epoch 57/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2912 - accuracy: 1.0000 - val_loss: 0.7122 - val_accuracy: 0.9150
# Epoch 58/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2709 - accuracy: 1.0000 - val_loss: 0.6921 - val_accuracy: 0.9100
# Epoch 59/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2539 - accuracy: 1.0000 - val_loss: 0.6726 - val_accuracy: 0.9250
# Epoch 60/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2389 - accuracy: 1.0000 - val_loss: 0.6514 - val_accuracy: 0.9300
# Epoch 61/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2248 - accuracy: 1.0000 - val_loss: 0.6371 - val_accuracy: 0.9250
# Epoch 62/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2097 - accuracy: 1.0000 - val_loss: 0.6161 - val_accuracy: 0.9250
# Epoch 63/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1975 - accuracy: 1.0000 - val_loss: 0.5956 - val_accuracy: 0.9200
# Epoch 64/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 1.0000 - val_loss: 0.5804 - val_accuracy: 0.9150
# Epoch 65/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1729 - accuracy: 1.0000 - val_loss: 0.5638 - val_accuracy: 0.9200
# Epoch 66/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 1.0000 - val_loss: 0.5447 - val_accuracy: 0.9250
# Epoch 67/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 1.0000 - val_loss: 0.5358 - val_accuracy: 0.9250
# Epoch 68/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1431 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.9300
# Epoch 69/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1338 - accuracy: 1.0000 - val_loss: 0.4965 - val_accuracy: 0.9250
# Epoch 70/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1262 - accuracy: 1.0000 - val_loss: 0.4854 - val_accuracy: 0.9350
# Epoch 71/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 1.0000 - val_loss: 0.4808 - val_accuracy: 0.9200
# Epoch 72/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1117 - accuracy: 1.0000 - val_loss: 0.4655 - val_accuracy: 0.9300
# Epoch 73/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1052 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.9400
# Epoch 74/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0988 - accuracy: 1.0000 - val_loss: 0.4437 - val_accuracy: 0.9450
# Epoch 75/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 1.0000 - val_loss: 0.4355 - val_accuracy: 0.9350
# Epoch 76/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0877 - accuracy: 1.0000 - val_loss: 0.4202 - val_accuracy: 0.9500
# Epoch 77/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 0.4327 - val_accuracy: 0.9300
# Epoch 78/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 1.0000 - val_loss: 0.4104 - val_accuracy: 0.9300
# Epoch 79/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0736 - accuracy: 1.0000 - val_loss: 0.3993 - val_accuracy: 0.9450
# Epoch 80/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 0.3960 - val_accuracy: 0.9350
# Epoch 81/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 0.3904 - val_accuracy: 0.9350
# Epoch 82/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.3870 - val_accuracy: 0.9450
# Epoch 83/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.3862 - val_accuracy: 0.9400
# Epoch 84/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 0.9550
# Epoch 85/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.3771 - val_accuracy: 0.9450
# Epoch 86/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.3692 - val_accuracy: 0.9400
# Epoch 87/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 1.0000 - val_loss: 0.3589 - val_accuracy: 0.9500
# Epoch 88/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.3405 - val_accuracy: 0.9600
# Epoch 89/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 1.0000 - val_loss: 0.3448 - val_accuracy: 0.9550
# Epoch 90/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.3397 - val_accuracy: 0.9600
# Epoch 91/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 1.0000 - val_loss: 0.3366 - val_accuracy: 0.9500
# Epoch 92/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.3498 - val_accuracy: 0.9450
# Epoch 93/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.3394 - val_accuracy: 0.9450
# Epoch 94/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.3265 - val_accuracy: 0.9400
# Epoch 95/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9450
# Epoch 96/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.9450
# Epoch 97/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.3266 - val_accuracy: 0.9450
# Epoch 98/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9550
# Epoch 99/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.3121 - val_accuracy: 0.9550
# Epoch 100/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.3110 - val_accuracy: 0.9550

# %%
# Evaluate the Model
predict = model.predict(x_test)
predict_labels, true_labels = [np.argmax(one_hot) for one_hot in predict], [np.argmax(one_hot) for one_hot in y_test]
print(classification_report(true_labels, predict_labels))
# Out:
# 7/7 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        23
#            1       0.95      1.00      0.97        18
#            2       1.00      1.00      1.00         8
#            3       0.67      0.67      0.67         3
#            4       1.00      1.00      1.00         7
#            5       0.94      1.00      0.97        16
#            6       1.00      1.00      1.00        12
#            7       0.91      0.91      0.91        11
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         8
#           10       1.00      1.00      1.00        12
#           11       1.00      1.00      1.00         1
#           12       1.00      0.71      0.83         7
#           13       0.88      1.00      0.93         7
#           14       1.00      1.00      1.00        10
#           15       0.60      0.38      0.46         8
#           16       0.92      1.00      0.96        11
#           17       1.00      0.86      0.92         7
#           18       0.95      1.00      0.98        21
#           19       1.00      1.00      1.00         6
#
#     accuracy                           0.94       200
#    macro avg       0.94      0.92      0.93       200
# weighted avg       0.94      0.94      0.94       200
